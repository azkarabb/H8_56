# %%
import folium
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

print('All item has been imported')
# Out:
# All item has been imported

# %%
df_london = pd.read_csv('london_crime_by_lsoa.csv')

print('Displat the top 5 row of data set')

print(df_london.head())
# Out:
# Displat the top 5 row of data set
#    lsoa_code     borough               major_category  \
# 0  E01001116     Croydon                     Burglary
# 1  E01001646   Greenwich  Violence Against the Person
# 2  E01000677     Bromley  Violence Against the Person
# 3  E01003774   Redbridge                     Burglary
# 4  E01004563  Wandsworth                      Robbery
#
#                 minor_category  value  year  month
# 0  Burglary in Other Buildings      0  2016     11
# 1               Other violence      0  2016     11
# 2               Other violence      0  2015      5
# 3  Burglary in Other Buildings      0  2016      3
# 4            Personal Property      0  2008      6

# %%
print('To Print the Dimension of Dataframe')
print(df_london.shape)
# Out:
# To Print the Dimension of Dataframe
# (13490604, 7)

# %%
print('To Display Column Values')

df1 = df_london.head(10)
df1.columns.values
# Out:
# To Display Column Values
# array(['lsoa_code', 'borough', 'major_category', 'minor_category',
#        'value', 'year', 'month'], dtype=object)

# %%
print('To Check if any columns has null values')
print(df_london.isnull().any())
# Out:
# To Check if any columns has null values
# lsoa_code         False
# borough           False
# major_category    False
# minor_category    False
# value             False
# year              False
# month             False
# dtype: bool

# %%
df2 = df_london[['borough', 'value']]

# %%
Year = df_london['year'].unique()
sumsandyear = df_london.groupby('year').sum()
sums = sumsandyear['value'].to_numpy()

n = len(Year)

for i in range(n):
    for j in range(0, n-i-1):
        if Year[j] > Year[j + 1]:
            Year[j], Year[j+1] = Year[j+1], Year[j]
            sums[j], sums[j+1] = sums[j+1], sums[j]
    
print('Years: ')
print(Year)
print('Sum of Crimes in London')
print(sum)
print('Line graph of crime in 2012 to 2020')

pos1 = np.arange(len(Year))
font2 = {'family': 'Impact',
        'color' : 'darkgreen',
        'weight' : 'bold',
        'size' : 30,
        }

plt.xticks(pos1, Year)
plt.plot(sums, color = 'darkgreen')
plt.xticks(pos1, Year)
plt.title('Number of Crimes in 2008 until 2019\n', fontdict = font2)
plt.xticks(rotation = -45)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
plt.xticks(color = 'green')
plt.yticks(color = 'red')
ax = plt.axes()
ax.set_facecolor('skyblue')

plt.show()
# Out:
# Years:
# [2008 2009 2010 2011 2012 2013 2014 2015 2016]
# Sum of Crimes in London
# <built-in function sum>
# Line graph of crime in 2012 to 2020
# <ipython-input-7-a4b4569922a7>:35: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()

# %%
font1 = {'family': 'Franklin Gothic Medium',
        'color' : 'darkblue',
        'weight' : 'bold',
        'size' : 35,
        }

labels = df_london['major_category'].unique()
sizes = df_london.groupby(['major_category']).size()
colors = ['darkgreen', 'lightskyblue', 'teal', 'purple', 'deepskyblue', 'slateblue', 'lightgreen', 'cornflowerblue', 'paleturquoise']

plt.figure(figsize = (20,10))
ax = plt.axes()
ax.set_facecolor('darkgreen')

plt.title('Percentage of Crime in each Type Category\n', fontdict = font1)
ab = plt.pie(sizes, labels = labels, colors = colors, startangle = 90, autopct ='%1.1f%%', textprops = {'fontsize' : 14, 'color' : 'darkblue'})

plt.show()

# %%
font = {'family' : 'Courier New',
       'color' : 'darkred',
       'weight' : 'bold',
       'size' : 40,
       }

label = df_london['major_category'].unique()
print('Type of Crime that are taking place')
print(label)

pos = np.arange(len(label))
totals = df_london.groupby('major_category').sum()
Totals = totals['value'].to_numpy()
print('Total no of crime that took place in each category')
print(Totals)

colors1 = ['lightcoral', 'darkred', 'salmon', 'coral', 'darksalmon', 'indianred', 'crimson', 'firebrick', 'sienna']
plt.figure(figsize = (20,10))
plt.bar(pos, Totals, color = colors1, width = 0.6)

ax = plt.axes()
ax.set_facecolor('skyblue')
plt.margins(0.05)
plt.xticks(pos, label)
plt.xticks(rotation = -45)
plt.xticks(fontsize = 19, color = 'darkred')
plt.yticks(fontsize = 19, color = 'darkblue')
plt.ylabel('No of Crimes', fontsize = 25, color = 'darkgreen')
plt.title('Barchart of Crime in Each Type\n', fontdict = font)

plt.show()
# Out:
# Type of Crime that are taking place
# ['Burglary' 'Violence Against the Person' 'Robbery' 'Theft and Handling'
#  'Criminal Damage' 'Drugs' 'Fraud or Forgery' 'Other Notifiable Offences'
#  'Sexual Offences']
# Total no of crime that took place in each category
# [ 754293  630938  470765    5325  106349  258873    1273 2661861 1558081]
# <ipython-input-9-c7e2bd5becc4>:21: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()

# %%
font = {'family' : 'Verdana',
       'color' : 'darkkhaki',
       'weight' : 'bold',
       'size' : 40,
       }

year2016 = df_london.loc[df_london['year'] == 2016]
months = year2016['month'].unique()

months.sort()

sum_month = year2016.groupby(['month']).sum()

Values = sum_month['value'].to_numpy()
name_of_months = ['Jan', 'Feb', 'Mar', 'Apr', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
print('Nomor of Crime in each month in 2016')
print(name_of_months)
print(Values)

n1 = np.arange(len(months))
xrange = range(1,13)

plt.figure(figsize = (20,10))
ax = plt.axes()
ax.set_facecolor('lightyellow')
plt.scatter(xrange, Values, s = 250, color = 'darkgoldenrod', cmap = 'viridis', alpha = 1)
plt.title('Numbers of Crime in Each Month in 2016\n', fontdict = font)
plt.xlabel('Months', fontsize = 30, color = 'goldenrod')
plt.ylabel('Number of Crimes', fontsize = 30, color = 'goldenrod')

plt.xticks(n1, name_of_months)
plt.xticks(color = 'goldenrod', fontsize = 20)
plt.ylabel(color = 'goldenrod', fontsize = 20)
# Out:
# Nomor of Crime in each month in 2016
# ['Jan', 'Feb', 'Mar', 'Apr', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# [58847 56697 59167 58637 63990 62262 65519 62666 61412 63405 61064 62455]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-1b437b5d16e7> in <module>
#      29 plt.ylabel('Number of Crimes', fontsize = 30, color = 'goldenrod')
#      30
# ---> 31 plt.xticks(n1, name_of_months)
#      32 plt.xticks(color = 'goldenrod', fontsize = 20)
#      33 plt.ylabel(color = 'goldenrod', fontsize = 20)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in xticks(ticks, labels, **kwargs)
#    1657         labels = ax.get_xticklabels()
#    1658     else:
# -> 1659         labels = ax.set_xticklabels(labels, **kwargs)
#    1660     for l in labels:
#    1661         l.update(kwargs)
#
# ...

# %%
print("Crime rate in boroughs of london")
print("please zoom in to view the map")
df2=df_london[['borough','value']]
world_geo = r'https://raw.githubusercontent.com/radoi90/housequest-data/master/london_boroughs.geojson' 
world_map=folium.Map(location=[54.237933,-2.36967],zoom_start=5,tiles = 'Mapbox Bright')

world_map.choropleth(
    geo_data=world_geo,
    name='choropleth',
    data=df2,
    columns=['borough', 'value'],
    key_on='feature.properties.name',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Crime rate in boroughs of london'
    
)

#folium.LayerControl().add_to(world_map)
world_map.save('LondonCrime.html')
display(world_map)

# %%
print("Ploting pairwise of columns")
sns.pairplot(df_london)
# Out:
# Ploting pairwise of columns
